# %% [markdown]
# # Imports

# %%
import pandas as pd
import gzip
import json
import re
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv("/content/drive/MyDrive/Uni/IUI/Data/final_dataset.csv", engine='python', error_bad_lines=False)
df.head()
# Out:
#    Unnamed: 0 overall  ...                                  summary        category
# 0           0     2.0  ...  These were recommended by my Podiatrist  AMAZON_FASHION
# 1           1     2.0  ...      Not the same as all my other pairs.  AMAZON_FASHION
# 2           2     2.0  ...  These were recommended by my Podiatrist  AMAZON_FASHION
# 3           3     2.0  ...      Not the same as all my other pairs.  AMAZON_FASHION
# 4           4     1.0  ...                                 One Star  AMAZON_FASHION
#
# [5 rows x 7 columns]

# %% [markdown]
# ## Keep only needed categories

# %%
categories = ['AMAZON_FASHION','All_Beauty','Appliances','Books','Digital_Music','Gift_Cards','Magazine_Subscriptions','Office_Products','Pet_Supplies','Software']
category = 9
indexNames = df[df['category'] == categories[category]].index
df.drop(indexNames , inplace=True)
df.head()

# %% [markdown]
# ## Minor Cleanup

# %%
df.drop(columns='Unnamed: 0', inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()

# %% [markdown]
# # Export Final Dataset

# %%
df.to_csv('/content/drive/MyDrive/Uni/IUI/Data/final_dataset_v2.csv')
print('Exported final dataset.')
# Out:
# Exported final dataset.
